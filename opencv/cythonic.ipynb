# %%
# %load_ext cython

# %%
# %%cython
#
# cdef int a = 0
# for i in range(10):
#     a += i
# print(a)
# Out:
# ---------------------------------------------------------------------------
# DistutilsPlatformError                    Traceback (most recent call last)
# d:\pyth\sem 2 projects\opencv\cythonic.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/pyth/sem%202%20projects/opencv/cythonic.ipynb#ch0000001?line=0'>1</a> get_ipython().run_cell_magic('cython', '', '\na: cython.int = 0\nfor i in range(10):\n    a += i\nprint(a)\n')
#
# File c:\Users\johan\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:2257, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    <a href='file:///c%3A/Users/johan/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=2254'>2255</a> with self.builtin_trap:
#    <a href='file:///c%3A/Users/johan/AppData/Local/Programs/Python/Python310/lib/site-packages/IPython/core/interactiveshell.py?line=2255'>2256</a>     args = (magic_arg_s, cell)
# ...
